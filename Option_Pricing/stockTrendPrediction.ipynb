# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split

# Define random_state for reproducibility
random_state = 42

# ----- Load Stock and Sentiment Data -----
stock_data = pd.read_csv('AAPL_trend.csv', parse_dates=['date'])
sentiment_data = pd.read_csv('sentiment_scores_title.csv', parse_dates=['date'])

# Merge sentiment scores with stock data on 'date'
stock_data['date'] = pd.to_datetime(stock_data['date'])
merged_data = pd.merge(stock_data, sentiment_data, on='date', how='left')

# ----- Define Date Range and Filter Stock Data -----
start_date = pd.to_datetime("2024-02-12")
end_date = pd.to_datetime("2025-02-19")
selected_stock_data = merged_data[(merged_data['date'] >= start_date) & (merged_data['date'] <= end_date)]

# ----- Feature Engineering for LSTM -----
X_days = 7  # Use previous 7 days of stock data
Y_days = 1  # Use 1 day of sentiment data

selected_stock_data = selected_stock_data.sort_values('date')
dates = selected_stock_data['date'].dt.strftime('%Y-%m-%d').tolist()
closing_values = selected_stock_data['closingValue'].values
sentiment_scores = selected_stock_data['sentiment_score'].values
trends = selected_stock_data['trend'].values

# Map trends to numerical labels
trend_to_label = {'increase': 0, 'decrease': 1, 'stable': 1}
labels_all = [trend_to_label[t] for t in trends]

features = []
labels = []

for i in range(max(X_days, Y_days), len(selected_stock_data)):
    stock_features = closing_values[i - X_days:i]
    sentiment_feature = sentiment_scores[i - Y_days:i]  # Use sentiment scores for the past Y_days

    feature_vector = np.concatenate([stock_features, sentiment_feature])
    features.append(feature_vector)
    labels.append(labels_all[i])

features = np.array(features)
labels = np.array(labels)
print(np.unique(labels, return_counts=True))

# ----- Train-Test Split with random_state -----
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=random_state, stratify=labels)

# ----- Define the LSTM Model -----
class StockTrendLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(StockTrendLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        out, _ = self.lstm(x, (h0, c0))
        out = out[:, -1, :]
        out = self.fc(out)
        return out

# Prepare the data for LSTM
input_size = 1
X_train_seq = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test_seq = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

X_train_tensor = torch.tensor(X_train_seq, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test_seq, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# Initialize and train the model
model = StockTrendLSTM(input_size=1, hidden_size=16, num_layers=1, num_classes=3)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

num_epochs = 30000
accuracies = []
for epoch in range(num_epochs):
    model.train()
    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if (epoch + 1) % 100 == 0:
        model.eval()
        with torch.no_grad():
            test_outputs = model(X_test_tensor)
            _, predicted = torch.max(test_outputs, 1)
            accuracy = (predicted == y_test_tensor).sum().item() / y_test_tensor.size(0)
            accuracies.append([epoch + 1, accuracy])
            print("Test Accuracy at epoch", epoch + 1, ":", accuracy)   

# Sort accuracies array by accuracy in descending order
accuracies = np.array(accuracies)
accuracies = accuracies[accuracies[:, 1].argsort()[::-1]]
print("Top 4 accuracies:")
for i in range(4):
    print(f"Epoch: {int(accuracies[i][0])}, Accuracy: {accuracies[i][1]}")
# Out:
# (array([0, 1]), array([145, 104]))
# Test Accuracy at epoch 100 : 0.62
# Test Accuracy at epoch 200 : 0.58
# Test Accuracy at epoch 300 : 0.58
# Test Accuracy at epoch 400 : 0.58
# Test Accuracy at epoch 500 : 0.58
# Test Accuracy at epoch 600 : 0.58
# Test Accuracy at epoch 700 : 0.58
# Test Accuracy at epoch 800 : 0.58
# Test Accuracy at epoch 900 : 0.58
# Test Accuracy at epoch 1000 : 0.58
# Test Accuracy at epoch 1100 : 0.58
# Test Accuracy at epoch 1200 : 0.58
# Test Accuracy at epoch 1300 : 0.58
# Test Accuracy at epoch 1400 : 0.58
# Test Accuracy at epoch 1500 : 0.58
# Test Accuracy at epoch 1600 : 0.58
# Test Accuracy at epoch 1700 : 0.58
# Test Accuracy at epoch 1800 : 0.58
# Test Accuracy at epoch 1900 : 0.58
# Test Accuracy at epoch 2000 : 0.58
# Test Accuracy at epoch 2100 : 0.58
# Test Accuracy at epoch 2200 : 0.58
# Test Accuracy at epoch 2300 : 0.58
# Test Accuracy at epoch 2400 : 0.58
# Test Accuracy at epoch 2500 : 0.58
# Test Accuracy at epoch 2600 : 0.58
# Test Accuracy at epoch 2700 : 0.58
# Test Accuracy at epoch 2800 : 0.58
# Test Accuracy at epoch 2900 : 0.58
# Test Accuracy at epoch 3000 : 0.58
# Test Accuracy at epoch 3100 : 0.58
# Test Accuracy at epoch 3200 : 0.58
# Test Accuracy at epoch 3300 : 0.58
# Test Accuracy at epoch 3400 : 0.58
# Test Accuracy at epoch 3500 : 0.58
# Test Accuracy at epoch 3600 : 0.58
# Test Accuracy at epoch 3700 : 0.58
# Test Accuracy at epoch 3800 : 0.58
# Test Accuracy at epoch 3900 : 0.58
# Test Accuracy at epoch 4000 : 0.58
# Test Accuracy at epoch 4100 : 0.58
# Test Accuracy at epoch 4200 : 0.58
# Test Accuracy at epoch 4300 : 0.6
# Test Accuracy at epoch 4400 : 0.62
# Test Accuracy at epoch 4500 : 0.6
# Test Accuracy at epoch 4600 : 0.58
# Test Accuracy at epoch 4700 : 0.58
# Test Accuracy at epoch 4800 : 0.58
# Test Accuracy at epoch 4900 : 0.58
# Test Accuracy at epoch 5000 : 0.58
# Test Accuracy at epoch 5100 : 0.58
# Test Accuracy at epoch 5200 : 0.58
# Test Accuracy at epoch 5300 : 0.58
# Test Accuracy at epoch 5400 : 0.58
# Test Accuracy at epoch 5500 : 0.58
# Test Accuracy at epoch 5600 : 0.58
# Test Accuracy at epoch 5700 : 0.58
# Test Accuracy at epoch 5800 : 0.58
# Test Accuracy at epoch 5900 : 0.58
# Test Accuracy at epoch 6000 : 0.56
# Test Accuracy at epoch 6100 : 0.56
# Test Accuracy at epoch 6200 : 0.56
# Test Accuracy at epoch 6300 : 0.56
# Test Accuracy at epoch 6400 : 0.56
# Test Accuracy at epoch 6500 : 0.56
# Test Accuracy at epoch 6600 : 0.56
# Test Accuracy at epoch 6700 : 0.54
# Test Accuracy at epoch 6800 : 0.54
# Test Accuracy at epoch 6900 : 0.54
# Test Accuracy at epoch 7000 : 0.54
# Test Accuracy at epoch 7100 : 0.54
# Test Accuracy at epoch 7200 : 0.52
# Test Accuracy at epoch 7300 : 0.54
# Test Accuracy at epoch 7400 : 0.54
# Test Accuracy at epoch 7500 : 0.54
# Test Accuracy at epoch 7600 : 0.56
# Test Accuracy at epoch 7700 : 0.56
# Test Accuracy at epoch 7800 : 0.56
# Test Accuracy at epoch 7900 : 0.54
# Test Accuracy at epoch 8000 : 0.54
# Test Accuracy at epoch 8100 : 0.54
# Test Accuracy at epoch 8200 : 0.56
# Test Accuracy at epoch 8300 : 0.56
# Test Accuracy at epoch 8400 : 0.54
# Test Accuracy at epoch 8500 : 0.54
# Test Accuracy at epoch 8600 : 0.54
# Test Accuracy at epoch 8700 : 0.54
# Test Accuracy at epoch 8800 : 0.54
# Test Accuracy at epoch 8900 : 0.54
# Test Accuracy at epoch 16200 : 0.66
# Test Accuracy at epoch 16300 : 0.66
# Test Accuracy at epoch 16400 : 0.66
# Test Accuracy at epoch 16500 : 0.66
# Test Accuracy at epoch 16600 : 0.66
# Test Accuracy at epoch 16700 : 0.66
# Test Accuracy at epoch 16800 : 0.66
# Test Accuracy at epoch 16900 : 0.66
# Test Accuracy at epoch 17000 : 0.66
# Test Accuracy at epoch 17100 : 0.66
# Test Accuracy at epoch 17200 : 0.66
# Test Accuracy at epoch 17300 : 0.66
# Test Accuracy at epoch 17400 : 0.64
# Test Accuracy at epoch 17500 : 0.64
# Test Accuracy at epoch 17600 : 0.64
# Test Accuracy at epoch 17700 : 0.64
# Test Accuracy at epoch 17800 : 0.64
# Test Accuracy at epoch 17900 : 0.66
# Test Accuracy at epoch 18000 : 0.64
# Test Accuracy at epoch 18100 : 0.62
# Test Accuracy at epoch 18200 : 0.62
# Test Accuracy at epoch 18300 : 0.62
# Test Accuracy at epoch 18400 : 0.56
# Test Accuracy at epoch 18500 : 0.62
# Test Accuracy at epoch 18600 : 0.62
# Test Accuracy at epoch 18700 : 0.6
# Test Accuracy at epoch 18800 : 0.62
# Test Accuracy at epoch 18900 : 0.62
# Test Accuracy at epoch 19000 : 0.64
# Test Accuracy at epoch 19100 : 0.64
# Test Accuracy at epoch 19200 : 0.66
# Test Accuracy at epoch 19300 : 0.66
# Test Accuracy at epoch 19400 : 0.66
# Test Accuracy at epoch 19500 : 0.64
# Test Accuracy at epoch 19600 : 0.64
# Test Accuracy at epoch 19700 : 0.64
# Test Accuracy at epoch 19800 : 0.6
# Test Accuracy at epoch 19900 : 0.6
# Test Accuracy at epoch 20000 : 0.62
# Test Accuracy at epoch 20100 : 0.62
# Test Accuracy at epoch 20200 : 0.62
# Test Accuracy at epoch 20300 : 0.62
# Test Accuracy at epoch 20400 : 0.62
# Test Accuracy at epoch 20500 : 0.64
# Test Accuracy at epoch 20600 : 0.64
# Test Accuracy at epoch 20700 : 0.64
# Test Accuracy at epoch 20800 : 0.64
# Test Accuracy at epoch 20900 : 0.64
# Test Accuracy at epoch 21000 : 0.64
# Test Accuracy at epoch 21100 : 0.58
# Test Accuracy at epoch 21200 : 0.62
# Test Accuracy at epoch 21300 : 0.6
# Test Accuracy at epoch 21400 : 0.6
# Test Accuracy at epoch 21500 : 0.6
# Test Accuracy at epoch 21600 : 0.6
# Test Accuracy at epoch 21700 : 0.6
# Test Accuracy at epoch 21800 : 0.6
# Test Accuracy at epoch 21900 : 0.6
# Test Accuracy at epoch 22000 : 0.6
# Test Accuracy at epoch 22100 : 0.6
# Test Accuracy at epoch 22200 : 0.6
# Test Accuracy at epoch 22300 : 0.6
# Test Accuracy at epoch 22400 : 0.62
# Test Accuracy at epoch 22500 : 0.6
# Test Accuracy at epoch 22600 : 0.6
# Test Accuracy at epoch 22700 : 0.6
# Test Accuracy at epoch 22800 : 0.62
# Test Accuracy at epoch 22900 : 0.64
# Test Accuracy at epoch 23000 : 0.64
# Test Accuracy at epoch 23100 : 0.64
# Test Accuracy at epoch 23200 : 0.64
# Test Accuracy at epoch 23300 : 0.64
# Test Accuracy at epoch 23400 : 0.64
# Test Accuracy at epoch 23500 : 0.64
# Test Accuracy at epoch 23600 : 0.64
# Test Accuracy at epoch 23700 : 0.64
# Test Accuracy at epoch 23800 : 0.64
# Test Accuracy at epoch 23900 : 0.64
# Test Accuracy at epoch 24000 : 0.62
# Test Accuracy at epoch 24100 : 0.62
# Test Accuracy at epoch 24200 : 0.6
# Test Accuracy at epoch 24300 : 0.6
# Test Accuracy at epoch 24400 : 0.6
# Test Accuracy at epoch 24500 : 0.62
# Test Accuracy at epoch 24600 : 0.62
# Test Accuracy at epoch 24700 : 0.62
# Test Accuracy at epoch 24800 : 0.62
# Test Accuracy at epoch 24900 : 0.62
# Test Accuracy at epoch 25000 : 0.62
# Test Accuracy at epoch 25100 : 0.6
# Test Accuracy at epoch 25200 : 0.64
# Test Accuracy at epoch 25300 : 0.6
# Test Accuracy at epoch 25400 : 0.64
# Test Accuracy at epoch 25500 : 0.62
# Test Accuracy at epoch 25600 : 0.64
# Test Accuracy at epoch 25700 : 0.64
# Test Accuracy at epoch 25800 : 0.6
# Test Accuracy at epoch 25900 : 0.64
# Test Accuracy at epoch 26000 : 0.6
# Test Accuracy at epoch 26100 : 0.6
# Test Accuracy at epoch 26200 : 0.6
# Test Accuracy at epoch 26300 : 0.6
# Test Accuracy at epoch 26400 : 0.6
# Test Accuracy at epoch 26500 : 0.6
# Test Accuracy at epoch 26600 : 0.6
# Test Accuracy at epoch 26700 : 0.6
# Test Accuracy at epoch 26800 : 0.6
# Test Accuracy at epoch 26900 : 0.64
# Test Accuracy at epoch 27000 : 0.6
# Test Accuracy at epoch 27100 : 0.6
# Test Accuracy at epoch 27200 : 0.6
# Test Accuracy at epoch 27300 : 0.62
# Test Accuracy at epoch 27400 : 0.64
# Test Accuracy at epoch 27500 : 0.64
# Test Accuracy at epoch 27600 : 0.64
# Test Accuracy at epoch 27700 : 0.62
# Test Accuracy at epoch 27800 : 0.68
# Test Accuracy at epoch 27900 : 0.62
# Test Accuracy at epoch 28000 : 0.62
# Test Accuracy at epoch 28100 : 0.62
# Test Accuracy at epoch 28200 : 0.6
# Test Accuracy at epoch 28300 : 0.6
# Test Accuracy at epoch 28400 : 0.66
# Test Accuracy at epoch 28500 : 0.62
# Test Accuracy at epoch 28600 : 0.6
# Test Accuracy at epoch 28700 : 0.68
# Test Accuracy at epoch 28800 : 0.64
# Test Accuracy at epoch 28900 : 0.6
# Test Accuracy at epoch 29000 : 0.64
# Test Accuracy at epoch 29100 : 0.64
# Test Accuracy at epoch 29200 : 0.6
# Test Accuracy at epoch 29300 : 0.6
# Test Accuracy at epoch 29400 : 0.62
# Test Accuracy at epoch 29500 : 0.62
# Test Accuracy at epoch 29600 : 0.62
# Test Accuracy at epoch 29700 : 0.62
# Test Accuracy at epoch 29800 : 0.62
# Test Accuracy at epoch 29900 : 0.62
# Test Accuracy at epoch 30000 : 0.62
# Top 4 accuracies:
# Epoch: 14700, Accuracy: 0.7
# Epoch: 14100, Accuracy: 0.7
# Epoch: 14200, Accuracy: 0.7
# Epoch: 13900, Accuracy: 0.7
